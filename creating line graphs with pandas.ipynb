# %%
import pandas as pd

# %%
df = pd.DataFrame({
   'pig': [3.49, 2.59, 2.97, 2.09, 3.02, 3.68, 3.04, 2.85],
  
   }, index=[1, 2, 3, 4, 5, 6, 7, 8])
lines = df.plot.line()

# %%
df = pd.DataFrame({
   'horse': [3.33, 2.86, 2.7,2.62,2.74, 3.47,2.89,3.32]
   }, index=[1, 2, 3, 4, 5, 6, 7, 8])
lines = df.plot.line()
